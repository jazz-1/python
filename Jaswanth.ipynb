# %% [markdown]
# #import library

# %%
import pandas as pd 
from matplotlib import pyplot as plot_matplt
import numpy as np

# %% [markdown]
# #creating  function

# %%
#creating  function 
def read_data(dataset):
    data1=pd.read_csv(dataset,skiprows=4)
    # read csv file and skip 4 rows
    data2=data1.drop(['Indicator Code', 'Country Code', 'Indicator Name', 'Unnamed: 66'],axis=1)
    # drop  columns 
    data3=data2.set_index("Country Name")
     # set index name 
    data4=data3.T
    # transpose dataset
    data4.reset_index(inplace=True)
    # reset index name 
    data4.rename(columns = {'index':'Year'}, inplace = True)
    # rename index name 
    return data1,data4 #

# %% [markdown]
# #Read path

# %%
dataset="/content/Agriculture.csv" # read dataset path
data_frame1,data_frame2=read_data(dataset) # reading data 
data_frame1.head()
 # showing dataset
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
#
#                                       Indicator Name     Indicator Code  \
# 0  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 1  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 2           Rural population (% of total population)     SP.RUR.TOTL.ZS
# 3                 Rural population growth (annual %)     SP.RUR.TOTL.ZG
# 4                                   Rural population        SP.RUR.TOTL
#
#         1960          1961          1962          1963          1964  \
# 0        NaN           NaN           NaN           NaN           NaN
# 1        NaN           NaN           NaN           NaN           NaN
# 2     49.224     49.239000     49.254000     49.270000     49.285000
# 3        NaN      2.267688      1.462057      0.859208      0.610248
# 4  26683.000  27295.000000  27697.000000  27936.000000  28107.000000
#
#           1965  ...          2013          2014          2015          2016  \
# 0          NaN  ...      0.046919      0.055358      0.092621      0.085188
# 1          NaN  ...      0.303687      0.398228      0.496427      0.335550
# 2     49.30000  ...     57.010000     56.959000     56.892000     56.808000
# 3      0.60301  ...      0.525061      0.502019      0.423733      0.354822
# 4  28277.00000  ...  58814.000000  59110.000000  59361.000000  59572.000000
#
#            2017          2018          2019          2020          2021  \
# 0      0.079480      0.076267      0.104098      0.069199      0.102736
# 1      0.297792      0.311423      0.350670      0.339582      0.353604
# 2     56.707000     56.589000     56.454000     56.303000     56.134000
# 3      0.293332      0.250744      0.198477      0.159830      0.101426
# 4  59747.000000  59897.000000  60016.000000  60112.000000  60173.000000
#
#    Unnamed: 66
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# # Printing data frame 2

# %%
data_frame2.head() #printing dataset
# Out:
# Country Name  Year  Aruba  Aruba   Aruba     Aruba    Aruba  Aruba  Aruba  \
# 0             1960    NaN    NaN  49.224       NaN  26683.0    NaN    NaN
# 1             1961    NaN    NaN  49.239  2.267688  27295.0    NaN    NaN
# 2             1962    NaN    NaN  49.254  1.462057  27697.0    NaN    NaN
# 3             1963    NaN    NaN  49.270  0.859208  27936.0    NaN    NaN
# 4             1964    NaN    NaN  49.285  0.610248  28107.0    NaN    NaN
#
# Country Name  Aruba  Aruba  ...  Zimbabwe   Zimbabwe  Zimbabwe  Zimbabwe  \
# 0               NaN    NaN  ...       NaN        NaN       NaN       NaN
# 1               NaN    NaN  ...  0.258498  1377015.0  4.872690  0.482710
# 2               NaN    NaN  ...  0.258498  1352412.0  5.001939  0.479054
# 3               NaN    NaN  ...  0.258498  1253451.0  5.131188  0.475025
# 4               NaN    NaN  ...  0.258498  1253793.0  5.260437  0.470754
#
# Country Name   Zimbabwe   Zimbabwe  Zimbabwe   Zimbabwe    Zimbabwe  Zimbabwe
# 0                   NaN        NaN       NaN        NaN         NaN       NaN
# 1             1885000.0  28.396019  109850.0  21.957560  376.272727   12567.0
# 2             1935000.0  28.615743  110700.0  20.211886  355.545455   12860.0
# 3             1985000.0  28.835466  111550.0  24.231738  320.666667   13000.0
# 4             2035000.0  29.055189  112400.0  33.906634  460.000000   13300.0
#
# [5 rows x 11173 columns]

# %% [markdown]
# # Showing Correlation Rural population (% of total population)

# %%
data_corr = data_frame1[data_frame1['Indicator Name']=='Rural population (% of total population)']  

data_corr_1 = data_corr.pivot_table(index=['Country Name'], values = ['1985', '1995', '2015', '2021']) 
 
data_corr_1.head(10)
# Out:
#                                   1985       1995       2015       2021
# Country Name
# Afghanistan                  81.003000  78.376000  75.197000  73.686000
# Africa Eastern and Southern  77.436028  72.830383  65.594916  62.716935
# Africa Western and Central   72.254004  66.907482  55.218627  51.550098
# Albania                      64.917000  61.089000  42.566000  37.031000
# Algeria                      52.032000  44.003000  29.152000  25.739000
# American Samoa               22.238000  14.720000  12.762000  12.831000
# Andorra                       4.841000   6.339000  11.655000  12.142000
# Angola                       69.662000  55.831000  36.554000  32.540000
# Antigua and Barbuda          64.979000  66.039000  75.000000  75.620000
# Arab World                   52.166787  48.104314  41.968534  40.262086

# %% [markdown]
# #Plotting Bar Graph For Agricultural nitrous oxide emissions (% of total)

# %%
plot_matplt.rcParams.update({'font.size': 18}) # define fornt Size 
bar1= data_frame1[data_frame1['Indicator Name'] == 'Agricultural nitrous oxide emissions (% of total)']
bar2=bar1.pivot_table(index=['Country Name'], values=['1990', '1995', '2000', '2005']) 
# define figure size (20,7)
plot_matplt.rcParams['figure.figsize']=(20,7) 
bar3=bar2.head(22) # 
# set color name 
bar3.plot.bar(color=['Fuchsia', 'Blue', 'Chocolate',  'MediumSpringGreen', 'OrangeRed'])
plot_matplt.xlabel('Country')

plot_matplt.ylabel('Comparision')
# Set title Name 
plot_matplt.title('Agricultural nitrous oxide emissions (% of total)') 
# Showing graph 
plot_matplt.show();

# %% [markdown]
# # Plotting Bar Graph For Forest area (% of land area)

# %%
# define figure size
bar4= data_frame1[data_frame1['Indicator Name'] =='Forest area (% of land area)']
bar5=bar4.pivot_table(index=['Country Name'], values=['1990', '1995', '2000', '2005']) 
plot_matplt.rcParams['figure.figsize']=(20,7) 
bar6= bar5.head(25)
bar6.plot.bar(color=['GoldenRod', 'Maroon', 'Fuchsia',  'Blue'])
plot_matplt.xlabel('Country Name')

plot_matplt.ylabel('Comparision')

plot_matplt.title('Forest area (% of land area)') 
# define title name 
plot_matplt.show();

# %% [markdown]
# #Plotting  Time Series Graph  For Agriculture, forestry, and fishing, value added (% of GDP)

# %%
df_ts= data_frame1[data_frame1['Indicator Name']=='Agriculture, forestry, and fishing, value added (% of GDP)']  
df_ts1=df_ts.set_index("Country Name") 
df_ts2=df_ts1.drop([ 'Indicator Name', 'Indicator Code', 'Country Code', 'Unnamed: 66'],axis=1)
df_ts3=df_ts2.T
df_ts4 =df_ts3.reset_index()

# %%
df_ts5=df_ts4.pivot_table(index=['index'], values=['Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic', 'Algeria', 'East Asia & Pacific (excluding high income)', 'Early-demographic dividend', 'East Asia & Pacific'])
plot_matplt.figure(figsize = (18,8)) # define figure size 
plot_matplt.plot(df_ts5.head(40),'--')
plot_matplt.xticks(rotation=90) 
plot_matplt.legend(['Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic', 'Algeria', 'East Asia & Pacific (excluding high income)', 'Early-demographic dividend', 'East Asia & Pacific'],bbox_to_anchor =(1.0, 1.1), ncol = 1) 
plot_matplt.xlabel('Year')

plot_matplt.ylabel('Comparison ') 
 
plot_matplt.title('Agriculture, forestry, and fishing, value added (% of GDP)') 
# define title name 
plot_matplt.show() # showing graph

# %% [markdown]
# #Plotting  Time Series Graph  For Agricultural methane emissions (thousand metric tons of CO2 equivalent)

# %%
df_ts6= data_frame1[data_frame1['Indicator Name']== 'Agricultural methane emissions (thousand metric tons of CO2 equivalent)']  
df_ts7=df_ts6.set_index("Country Name") 
df_ts8=df_ts7.drop(['Indicator Name', 'Indicator Code', 'Country Code', 'Unnamed: 66'],axis=1)
df_ts9=df_ts8.T
df_ts10 = df_ts9.reset_index()

# %%
df_ts11=df_ts10.pivot_table(index=['index'], values=['Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic', 'Algeria', 'East Asia & Pacific (excluding high income)', 'Early-demographic dividend', 'East Asia & Pacific'])  
plot_matplt.figure(figsize = (18,8)) # define figure size 
plot_matplt.plot(df_ts11.head(40),'--')
plot_matplt.xticks(rotation=90) 
plot_matplt.legend(['Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica', 'Denmark', 'Dominican Republic', 'Algeria', 'East Asia & Pacific (excluding high income)', 'Early-demographic dividend', 'East Asia & Pacific'],bbox_to_anchor =(1.0, 1.1), ncol = 1) 
plot_matplt.xlabel('Year')

plot_matplt.ylabel('Comparison ') 

plot_matplt.title('Agricultural methane emissions (thousand metric tons of CO2 equivalent)') 

plot_matplt.show() # showing graph

# %% [markdown]
# # Plotting Correlation Matrix  For Country (Malaysia)

# %%
#creating function for country
def function(Country):
  matrix = data_frame1[data_frame1['Country Name']==f'{Country}'] 
  matrix = matrix.drop(['Country Name', 'Unnamed: 66', 'Country Code', 'Indicator Code'],axis=1) 
  matrix = matrix.T
  matrix1=matrix.iloc[0] 
  matrix=matrix[1:] 
  matrix.columns=matrix1
  matrix = matrix.reset_index(drop=True)
  return matrix

# %%
data_count=function('Malaysia') # fatch country name 
data_count.to_csv('Malaysia.csv') # create new data set file 
data_count1=pd.read_csv('/content/Malaysia.csv') # read dataset for Nepal country 
data1=data_count1.drop(['Unnamed: 0'],axis=1) # drop unnamed columns 
df_fill = data1.fillna(0)

# %%
df_matrix1 = df_fill[[ 'Agricultural machinery, tractors per 100 sq. km of arable land', 'Rural land area (sq. km)', 'Land area (sq. km)', 'Average precipitation in depth (mm per year)', 'Agricultural irrigated land (% of total agricultural land)', 'Forest area (% of land area)', 'Forest area (sq. km)']]

# %%
df_corr1=df_matrix1.corr() #correlation
df_corr1.head()
# Out:
#                                                     Agricultural machinery, tractors per 100 sq. km of arable land  \
# Agricultural machinery, tractors per 100 sq. km...                                           1.000000
# Rural land area (sq. km)                                                                     0.043367
# Land area (sq. km)                                                                           0.116009
# Average precipitation in depth (mm per year)                                                -0.051493
# Agricultural irrigated land (% of total agricul...                                          -0.226612
#
#                                                     Rural land area (sq. km)  \
# Agricultural machinery, tractors per 100 sq. km...                  0.043367
# Rural land area (sq. km)                                            1.000000
# Land area (sq. km)                                                  0.041169
# Average precipitation in depth (mm per year)                       -0.116147
# Agricultural irrigated land (% of total agricul...                 -0.080420
#
#                                                     Land area (sq. km)  \
# Agricultural machinery, tractors per 100 sq. km...            0.116009
# Rural land area (sq. km)                                      0.041169
# Land area (sq. km)                                            1.000000
# Average precipitation in depth (mm per year)                  0.094040
# Agricultural irrigated land (% of total agricul...            0.065113
#
#                                                     Average precipitation in depth (mm per year)  \
# Agricultural machinery, tractors per 100 sq. km...                                     -0.051493
# Rural land area (sq. km)                                                               -0.116147
# Land area (sq. km)                                                                      0.094040
# Average precipitation in depth (mm per year)                                            1.000000
# Agricultural irrigated land (% of total agricul...                                      0.064193
#
#                                                     Agricultural irrigated land (% of total agricultural land)  \
# Agricultural machinery, tractors per 100 sq. km...                                          -0.226612
# Rural land area (sq. km)                                                                    -0.080420
# Land area (sq. km)                                                                           0.065113
# Average precipitation in depth (mm per year)                                                 0.064193
# Agricultural irrigated land (% of total agricul...                                           1.000000
#
#                                                     Forest area (% of land area)  \
# Agricultural machinery, tractors per 100 sq. km...                      0.018776
# Rural land area (sq. km)                                                0.229397
# Land area (sq. km)                                                      0.182463
# Average precipitation in depth (mm per year)                            0.038424
# Agricultural irrigated land (% of total agricul...                      0.344743
#
#                                                     Forest area (sq. km)
# Agricultural machinery, tractors per 100 sq. km...              0.018776
# Rural land area (sq. km)                                        0.229397
# Land area (sq. km)                                              0.182463
# Average precipitation in depth (mm per year)                    0.038424
# Agricultural irrigated land (% of total agricul...              0.344743

# %%
import numpy as np 
arr=df_corr1.to_numpy()
Labels=df_matrix1.columns
figure, Axis = plot_matplt.subplots(figsize=(15,10)) 
im = Axis.imshow(df_corr1,cmap="YlGnBu_r")

Axis.set_xticks(np.arange(len(Labels)))
Axis.set_yticks(np.arange(len(Labels)))

Axis.set_xticklabels(Labels)
Axis.set_yticklabels(Labels)

plot_matplt.setp(Axis.get_xticklabels(), rotation=120, ha="right",rotation_mode="anchor") 

for i in range(len(Labels)):
    for j in range(len(Labels)):
        text = Axis.text(j, i, round(arr[i, j],2), ha="center", va="center", color="black") 

Axis.set_title("Malaysia") 
plot_matplt.show()

# %% [markdown]
# # Plotting Correlation Matrix  For Country (Bangladesh)

# %%
data_count2=function('Bangladesh') 
data_count2.to_csv('Bangladesh.csv') # create new data set file 
data_count3=pd.read_csv('/content/Bangladesh.csv') # read dataset for Nepal country 
data1=data_count3.drop(['Unnamed: 0'],axis=1) # drop unnamed columns 
df_fill = data1.fillna(0)

# %%
df_matrix2= df_fill[[ 'Agricultural machinery, tractors per 100 sq. km of arable land', 'Rural land area (sq. km)', 'Land area (sq. km)', 'Average precipitation in depth (mm per year)', 'Agricultural irrigated land (% of total agricultural land)', 'Forest area (% of land area)', 'Forest area (sq. km)']]

# %%
df_corr2=df_matrix2.corr() 
df_corr2.head()
# Out:
#                                                     Agricultural machinery, tractors per 100 sq. km of arable land  \
# Agricultural machinery, tractors per 100 sq. km...                                           1.000000
# Rural land area (sq. km)                                                                    -0.084678
# Land area (sq. km)                                                                           0.231205
# Average precipitation in depth (mm per year)                                                -0.056026
# Agricultural irrigated land (% of total agricul...                                          -0.405705
#
#                                                     Rural land area (sq. km)  \
# Agricultural machinery, tractors per 100 sq. km...                 -0.084678
# Rural land area (sq. km)                                            1.000000
# Land area (sq. km)                                                  0.041169
# Average precipitation in depth (mm per year)                       -0.116147
# Agricultural irrigated land (% of total agricul...                 -0.103043
#
#                                                     Land area (sq. km)  \
# Agricultural machinery, tractors per 100 sq. km...            0.231205
# Rural land area (sq. km)                                      0.041169
# Land area (sq. km)                                            1.000000
# Average precipitation in depth (mm per year)                  0.094040
# Agricultural irrigated land (% of total agricul...            0.083430
#
#                                                     Average precipitation in depth (mm per year)  \
# Agricultural machinery, tractors per 100 sq. km...                                     -0.056026
# Rural land area (sq. km)                                                               -0.116147
# Land area (sq. km)                                                                      0.094040
# Average precipitation in depth (mm per year)                                            1.000000
# Agricultural irrigated land (% of total agricul...                                     -0.039450
#
#                                                     Agricultural irrigated land (% of total agricultural land)  \
# Agricultural machinery, tractors per 100 sq. km...                                          -0.405705
# Rural land area (sq. km)                                                                    -0.103043
# Land area (sq. km)                                                                           0.083430
# Average precipitation in depth (mm per year)                                                -0.039450
# Agricultural irrigated land (% of total agricul...                                           1.000000
#
#                                                     Forest area (% of land area)  \
# Agricultural machinery, tractors per 100 sq. km...                     -0.547085
# Rural land area (sq. km)                                                0.227044
# Land area (sq. km)                                                      0.182562
# Average precipitation in depth (mm per year)                            0.038964
# Agricultural irrigated land (% of total agricul...                      0.449966
#
#                                                     Forest area (sq. km)
# Agricultural machinery, tractors per 100 sq. km...             -0.547085
# Rural land area (sq. km)                                        0.227044
# Land area (sq. km)                                              0.182562
# Average precipitation in depth (mm per year)                    0.038964
# Agricultural irrigated land (% of total agricul...              0.449966

# %%
arr=df_corr2.to_numpy()
Labels=df_matrix2.columns
figure, Axis = plot_matplt.subplots(figsize=(15,10)) 
im = Axis.imshow(df_corr2,cmap="cividis")

Axis.set_xticks(np.arange(len(Labels)))
Axis.set_yticks(np.arange(len(Labels)))

Axis.set_xticklabels(Labels)
Axis.set_yticklabels(Labels)

plot_matplt.setp(Axis.get_xticklabels(), rotation=120, ha="right",rotation_mode="anchor") 

for i in range(len(Labels)):
    for j in range(len(Labels)):
        text = Axis.text(j, i, round(arr[i, j],2), ha="center", va="center", color="black") 

Axis.set_title("Bangladesh") 
plot_matplt.show()
